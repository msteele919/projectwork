# %%
import pandas as pd

# %%
df_wind_save = pd.read_pickle('../Dataframes/df_wind_save.pkl')
df_wind_gbg = pd.read_pickle('../Dataframes/df_wind_gbg.pkl')

# %%
df_wind_save
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1951-01-01  00:00:00         100.0        G            3.0          G
# 1      1951-01-01  03:00:00         110.0        G            2.0          G
# 2      1951-01-01  06:00:00          70.0        G            2.0          G
# 3      1951-01-01  12:00:00          90.0        G            3.0          G
# 4      1951-01-01  15:00:00          70.0        G            4.0          G
# ...           ...       ...           ...      ...            ...        ...
# 430417 2006-12-05  09:00:00         190.0        G            8.0          G
# 430418 2006-12-05  10:00:00         190.0        Y            8.0          Y
# 430419 2006-12-05  11:00:00         200.0        Y            9.0          Y
# 430420 2006-12-05  12:00:00         200.0        G           11.0          G
# 430421 2006-12-05  13:00:00         190.0        Y           10.0          Y
#
# ...

# %%
df_wind_gbg
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1961-01-01  06:00:00         180.0        G            0.0          G
# 1      1961-01-01  12:00:00         180.0        G            4.0          G
# 2      1961-01-01  18:00:00         140.0        G            3.0          G
# 3      1961-01-02  06:00:00         180.0        G            4.0          G
# 4      1961-01-02  12:00:00         180.0        G            5.0          G
# ...           ...       ...           ...      ...            ...        ...
# 305146 2023-07-01  02:00:00         249.0        G            3.1          G
# 305147 2023-07-01  03:00:00         226.0        G            2.2          G
# 305148 2023-07-01  04:00:00         223.0        G            2.3          G
# 305149 2023-07-01  05:00:00         217.0        G            1.9          G
# 305150 2023-07-01  06:00:00         211.0        G            1.4          G
#
# ...

# %%
last_day_save = df_wind_save['Datum'][-1:]

# %%
last_day_save = str(last_day_save.values[0])[:10]

# %%
last_day_save
# Out:
# '2006-12-05'

# %%
df_wind_gbg = df_wind_gbg[df_wind_gbg['Datum'] > last_day_save]

# %%
df_wind_gbg
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 166842 2006-12-06  00:00:00         219.0        G            4.0          G
# 166843 2006-12-06  01:00:00         194.0        Y            2.7          Y
# 166844 2006-12-06  02:00:00         184.0        Y            4.5          Y
# 166845 2006-12-06  03:00:00         186.0        G            4.9          G
# 166846 2006-12-06  04:00:00         183.0        Y            6.3          Y
# ...           ...       ...           ...      ...            ...        ...
# 305146 2023-07-01  02:00:00         249.0        G            3.1          G
# 305147 2023-07-01  03:00:00         226.0        G            2.2          G
# 305148 2023-07-01  04:00:00         223.0        G            2.3          G
# 305149 2023-07-01  05:00:00         217.0        G            1.9          G
# 305150 2023-07-01  06:00:00         211.0        G            1.4          G
#
# ...

# %%
df_compiled_wind_data = pd.concat([df_wind_save, df_wind_gbg], ignore_index=True)

# %%
df_compiled_wind_data
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1951-01-01  00:00:00         100.0        G            3.0          G
# 1      1951-01-01  03:00:00         110.0        G            2.0          G
# 2      1951-01-01  06:00:00          70.0        G            2.0          G
# 3      1951-01-01  12:00:00          90.0        G            3.0          G
# 4      1951-01-01  15:00:00          70.0        G            4.0          G
# ...           ...       ...           ...      ...            ...        ...
# 568726 2023-07-01  02:00:00         249.0        G            3.1          G
# 568727 2023-07-01  03:00:00         226.0        G            2.2          G
# 568728 2023-07-01  04:00:00         223.0        G            2.3          G
# 568729 2023-07-01  05:00:00         217.0        G            1.9          G
# 568730 2023-07-01  06:00:00         211.0        G            1.4          G
#
# ...

# %%
# df_compiled_wind_data.to_csv('../data/prepared_data/compiled_wind_data_gbg_save.csv', mode='w', index=False)

# %%
# df_compiled_wind_data.to_pickle('../Dataframes/df_wind_gbg_save.pkl')
