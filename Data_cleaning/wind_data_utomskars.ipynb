# %%
import pandas as pd

# %%
df_wind_trubaduren = pd.read_pickle('../Dataframes/df_wind_trubaduren.pkl')
df_wind_vinga = pd.read_pickle('../Dataframes/df_wind_vinga.pkl')

# %%
# df_wind_utomskars = df_wind_trubaduren

# %%
df_wind_trubaduren
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1978-12-12  15:00:00         110.0        Y            6.0          Y
# 1      1978-12-12  21:00:00         110.0        Y            7.0          Y
# 2      1978-12-13  03:00:00          80.0        Y            6.0          Y
# 3      1978-12-13  09:00:00          90.0        Y            6.0          Y
# 4      1978-12-13  15:00:00         100.0        Y            8.0          Y
# ...           ...       ...           ...      ...            ...        ...
# 150492 2007-06-11  07:00:00         282.0        Y            3.5          Y
# 150493 2007-06-11  08:00:00         265.0        Y            2.4          Y
# 150494 2007-06-11  09:00:00         247.0        G            3.5          G
# 150495 2007-06-11  10:00:00         253.0        Y            2.2          Y
# 150496 2007-06-11  11:00:00         265.0        Y            2.9          Y
#
# ...

# %%
df_wind_vinga
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1926-01-01  01:00:00         290.0        G            8.0          G
# 1      1926-01-01  07:00:00          20.0        G            8.0          G
# 2      1926-01-01  13:00:00         360.0        G            4.0          G
# 3      1926-01-01  18:00:00         320.0        G            2.0          G
# 4      1926-01-01  20:00:00           0.0        G            0.0          G
# ...           ...       ...           ...      ...            ...        ...
# 275798 2023-07-01  02:00:00         248.0        G            6.1          G
# 275799 2023-07-01  03:00:00         230.0        G            7.7          G
# 275800 2023-07-01  04:00:00         224.0        G            7.0          G
# 275801 2023-07-01  05:00:00         209.0        G            7.0          G
# 275802 2023-07-01  06:00:00         191.0        G            5.9          G
#
# ...
