# %%
import pandas as pd

# %%
df = pd.read_pickle('../Dataframes\df_wind_gbg_save.pkl')

# %%
df
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1951-01-01  00:00:00         100.0        G            3.0          G
# 1      1951-01-01  03:00:00         110.0        G            2.0          G
# 2      1951-01-01  06:00:00          70.0        G            2.0          G
# 3      1951-01-01  12:00:00          90.0        G            3.0          G
# 4      1951-01-01  15:00:00          70.0        G            4.0          G
# ...           ...       ...           ...      ...            ...        ...
# 568726 2023-07-01  02:00:00         249.0        G            3.1          G
# 568727 2023-07-01  03:00:00         226.0        G            2.2          G
# 568728 2023-07-01  04:00:00         223.0        G            2.3          G
# 568729 2023-07-01  05:00:00         217.0        G            1.9          G
# 568730 2023-07-01  06:00:00         211.0        G            1.4          G
#
# ...

# %%
# df.drop(columns=('index'), inplace=True)

# %%
# df

# %%
# df.to_pickle('../Dataframes/df_compiled_monthly_precipitation_gbg_save2.pkl')

# %%
for i in range(1944, 2023):
    for ind, val in df.iterrows():
        if i == val['Year']:    
            year = val['Year']
            print(f'{year} // {ind}')
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\olofs\OneDrive\Skrivbord\DataScientist\Agilt Projektarbete\projectwork\Data_cleaning\check_index.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/olofs/OneDrive/Skrivbord/DataScientist/Agilt%20Projektarbete/projectwork/Data_cleaning/check_index.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> for i in range(1944, 2023):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/olofs/OneDrive/Skrivbord/DataScientist/Agilt%20Projektarbete/projectwork/Data_cleaning/check_index.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a>     for ind, val in df.iterrows():
#       <a href='vscode-notebook-cell:/c%3A/Users/olofs/OneDrive/Skrivbord/DataScientist/Agilt%20Projektarbete/projectwork/Data_cleaning/check_index.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a>         if i == val['Year']:
# ...
