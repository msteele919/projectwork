# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
windyboth = pd.read_pickle("../Dataframes/df_wind_gbg_save.pkl")
windyvinga = pd.read_pickle("../Dataframes/df_wind_vinga.pkl")
windytrubadur = pd.read_pickle("../Dataframes/df_wind_trubaduren.pkl")

# %%
windyboth
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1951-01-01  00:00:00         100.0        G            3.0          G
# 1      1951-01-01  03:00:00         110.0        G            2.0          G
# 2      1951-01-01  06:00:00          70.0        G            2.0          G
# 3      1951-01-01  12:00:00          90.0        G            3.0          G
# 4      1951-01-01  15:00:00          70.0        G            4.0          G
# ...           ...       ...           ...      ...            ...        ...
# 568726 2023-07-01  02:00:00         249.0        G            3.1          G
# 568727 2023-07-01  03:00:00         226.0        G            2.2          G
# 568728 2023-07-01  04:00:00         223.0        G            2.3          G
# 568729 2023-07-01  05:00:00         217.0        G            1.9          G
# 568730 2023-07-01  06:00:00         211.0        G            1.4          G
#
#         Year  Month  Snitt_per_dag  Max_uppmätta_hastighet
# 0       1951      1           3.29                     5.0
# 1       1951      1           3.29                     5.0
# 2       1951      1           3.29                     5.0
# 3       1951      1           3.29                     5.0
# 4       1951      1           3.29                     5.0
# ...      ...    ...            ...                     ...
# 568726  2023      7           2.47                     3.5
# 568727  2023      7           2.47                     3.5
# 568728  2023      7           2.47                     3.5
# 568729  2023      7           2.47                     3.5
# 568730  2023      7           2.47                     3.5
#
# [568731 rows x 10 columns]

# %%
fig, ax = plt.subplots(figsize=(28, 6))
sns.lineplot(data= windyboth, x= 'Datum', y = 'Max_uppmätta_hastighet')
plt.title('Högsta uppmätta vindhastigheten över tid i Göteborg')
plt.ylabel('Vindhastighet i meter per sekund')
plt.xlabel('År')
# plt.savefig("../plottar/vindhastighetgbg.png")
# Out:
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 0, 'År')

# %%
storm = windyboth.query("Max_uppmätta_hastighet >= 24.5")

# %%
storm
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 2531   1951-11-25  00:00:00         210.0        G           25.0          G
# 2532   1951-11-25  03:00:00         230.0        G           22.0          G
# 2533   1951-11-25  06:00:00         250.0        G           17.0          G
# 2534   1951-11-25  09:00:00         270.0        G           16.0          G
# 2535   1951-11-25  12:00:00         290.0        G           19.0          G
# 2536   1951-11-25  15:00:00         280.0        G           14.0          G
# 2537   1951-11-25  18:00:00         290.0        G           11.0          G
# 2538   1951-11-25  21:00:00         300.0        G            7.0          G
# 2555   1951-11-28  00:00:00         250.0        G           18.0          G
# 2556   1951-11-28  03:00:00         250.0        G           26.0          G
# 2557   1951-11-28  06:00:00         270.0        G           19.0          G
# 2558   1951-11-28  09:00:00         220.0        G           16.0          G
# 2559   1951-11-28  12:00:00         220.0        G           13.0          G
# 2560   1951-11-28  15:00:00         230.0        G           13.0          G
# 2561   1951-11-28  18:00:00         260.0        G           13.0          G
# 2562   1951-11-28  21:00:00         270.0        G            7.0          G
# 10707  1954-09-17  00:00:00         230.0        G           16.0          G
# 10708  1954-09-17  03:00:00         230.0        G           14.0          G
# 10709  1954-09-17  06:00:00         220.0        G           18.0          G
# 10710  1954-09-17  09:00:00         250.0        G           25.0          G
# 10711  1954-09-17  12:00:00         260.0        G           23.0          G
# 127586  1969      9          16.04                    26.0
# 127587  1969      9          16.04                    26.0
# 127588  1969      9          16.04                    26.0
# 127589  1969      9          16.04                    26.0
# 127590  1969      9          16.04                    26.0
# 127591  1969      9          16.04                    26.0
# 127592  1969      9          16.04                    26.0
# 127593  1969      9          16.04                    26.0
# 127594  1969      9          16.04                    26.0
# 127595  1969      9          16.04                    26.0
# 127596  1969      9          16.04                    26.0
# 127597  1969      9          16.04                    26.0

# %%
len(storm['Datum'].unique())
# Out:
# 4

# %%
print(f"Antal dagar med stormvindar på fastlandet: {len(storm['Datum'].unique())}")
print("Det har inte uppmätts svår storm vid mätstationerna på fastlandet.")
# Out:
# Antal dagar med stormvindar på fastlandet: 4
# Det har inte uppmätts svår storm vid mätstationerna på fastlandet.

# %% [markdown]
# # Varför blåser det mindre?

# %% [markdown]
# Med datan vi har som är från säve och göteborg så skulle det kunna bero på att staden vuxit, fler byggnader som fångar upp vinden innan den når mätstationen.
# Är det detsamma med vind-data utomskärs där ingenting står i vägen?

# %%
windyvinga
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1926-01-01  01:00:00         290.0        G            8.0          G
# 1      1926-01-01  07:00:00          20.0        G            8.0          G
# 2      1926-01-01  13:00:00         360.0        G            4.0          G
# 3      1926-01-01  18:00:00         320.0        G            2.0          G
# 4      1926-01-01  20:00:00           0.0        G            0.0          G
# ...           ...       ...           ...      ...            ...        ...
# 275798 2023-07-01  02:00:00         248.0        G            6.1          G
# 275799 2023-07-01  03:00:00         230.0        G            7.7          G
# 275800 2023-07-01  04:00:00         224.0        G            7.0          G
# 275801 2023-07-01  05:00:00         209.0        G            7.0          G
# 275802 2023-07-01  06:00:00         191.0        G            5.9          G
#
#         Year  Month  Snitt_per_dag  Max_uppmätta_hastighet
# 0       1926      1           4.40                     8.0
# 1       1926      1           4.40                     8.0
# 2       1926      1           4.40                     8.0
# 3       1926      1           4.40                     8.0
# 4       1926      1           4.40                     8.0
# ...      ...    ...            ...                     ...
# 275798  2023      7           6.96                     8.1
# 275799  2023      7           6.96                     8.1
# 275800  2023      7           6.96                     8.1
# 275801  2023      7           6.96                     8.1
# 275802  2023      7           6.96                     8.1
#
# [275803 rows x 10 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 6))
plt.title('Högst uppmätta vindhastighet utomskärs')
plt.ylabel('Vindhastighet i meter per sekund')
plt.xlabel('År')
plt.legend(loc = 'upper right', handles = ['Vinga', 'Trubaduren'], labels=['Vinga', 'Trubaduren'])
sns.lineplot(data = windyvinga, x = 'Datum', y = 'Max_uppmätta_hastighet')
sns.lineplot(data=windytrubadur, x='Datum', y='Högsta_vindhastighet')
# plt.savefig('../plottar/vindhastighetutomskars.png')
# Out:
# C:\Users\Stenb\AppData\Local\Temp\ipykernel_1756\2298009839.py:5: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   plt.legend(loc = 'upper right', handles = ['Vinga', 'Trubaduren'], labels=['Vinga', 'Trubaduren'])
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Stenb\anaconda3\envs\AP_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': 'Högst uppmätta vindhastighet utomskärs'}, xlabel='År', ylabel='Vindhastighet i meter per sekund'>

# %% [markdown]
# Som vi ser från denna datan tagen utomskärs, bortsett från den uteblivna datan så är vindhastigheten ungefär densamma över tid.
# Blå = Vinga,
# Orange = Trubaduren

# %%
orkanvinga = windyvinga.query("Max_uppmätta_hastighet >= 32.6")
svarstormvinga = windyvinga.query("Max_uppmätta_hastighet >= 28.5 and Max_uppmätta_hastighet <=32.5")
stormvinga = windyvinga.query("Max_uppmätta_hastighet >=24.5 and Max_uppmätta_hastighet <= 28.4")

# %%
print(stormvinga['Max_uppmätta_hastighet'].max())
print(svarstormvinga['Max_uppmätta_hastighet'].max())
print(orkanvinga['Max_uppmätta_hastighet'].max())
# Out:
# 27.0
# 31.0
# 36.0

# %%
len(stormvinga['Datum'].unique())
# Out:
# 51

# %%
print(f"Antal dagar med stormvindar utomskärs: {len(stormvinga['Datum'].unique())}")
print(f"Antal dagar med svåra stormvindar utomskärs: {len(svarstormvinga['Datum'].unique())}")
print(f"Antal dagar med orkanvindar utomskärs: {len(orkanvinga['Datum'].unique())}")
# Out:
# Antal dagar med stormvindar utomskärs: 51
# Antal dagar med svåra stormvindar utomskärs: 9
# Antal dagar med orkanvindar utomskärs: 1

# %% [markdown]
# Då ska vi bara ta reda på när dessa dagarna är.

# %%
stormvinga['Datum'].unique()
# Out:
# <DatetimeArray>
# ['1929-01-15 00:00:00', '1929-01-18 00:00:00', '1929-10-02 00:00:00',
#  '1929-11-11 00:00:00', '1929-12-10 00:00:00', '1931-12-15 00:00:00',
#  '1931-12-28 00:00:00', '1935-09-19 00:00:00', '1935-10-10 00:00:00',
#  '1938-11-24 00:00:00', '1949-01-01 00:00:00', '1949-01-20 00:00:00',
#  '1963-09-26 00:00:00', '1964-12-13 00:00:00', '1964-12-30 00:00:00',
#  '1965-01-11 00:00:00', '1965-09-09 00:00:00', '1967-04-17 00:00:00',
#  '1973-11-12 00:00:00', '1973-11-20 00:00:00', '1974-11-11 00:00:00',
#  '1975-01-06 00:00:00', '1975-01-22 00:00:00', '1975-12-02 00:00:00',
#  '1978-10-25 00:00:00', '1979-12-28 00:00:00', '1980-04-19 00:00:00',
#  '1981-11-21 00:00:00', '1982-08-12 00:00:00', '1982-11-16 00:00:00',
#  '1982-12-15 00:00:00', '1982-12-20 00:00:00', '1982-12-24 00:00:00',
#  '1983-10-19 00:00:00', '1985-10-12 00:00:00', '1986-12-02 00:00:00',
#  '1988-10-28 00:00:00', '1990-01-29 00:00:00', '1993-01-22 00:00:00',
#  '1993-03-19 00:00:00', '1996-11-07 00:00:00', '2008-01-31 00:00:00',
#  '2008-10-05 00:00:00', '2011-11-27 00:00:00', '2011-12-09 00:00:00',
#  '2012-01-04 00:00:00', '2013-12-05 00:00:00', '2013-12-06 00:00:00',
#  '2014-12-10 00:00:00', '2015-11-08 00:00:00', '2017-01-11 00:00:00']
# Length: 51, dtype: datetime64[ns]

# %%
stormvinga = stormvinga.drop_duplicates(subset='Datum')

# Create bins for 20-year intervals
bins = list(range(1920, 2040, 20))  # Adjust the start and end years as needed

# Group the data by 20-year intervals and count observations in each interval
interval_counts = stormvinga.groupby(pd.cut(stormvinga['Year'], bins=bins), observed=True).size()

# Print the result
print(interval_counts)
# Out:
# Year
# (1920, 1940]    10
# (1940, 1960]     2
# (1960, 1980]    15
# (1980, 2000]    14
# (2000, 2020]    10
# dtype: int64

# %%
svarstormvinga = svarstormvinga.drop_duplicates(subset='Datum')

# Create bins for 20-year intervals
bins1 = list(range(1920, 2040, 20))  # Adjust the start and end years as needed

# Group the data by 20-year intervals and count observations in each interval
interval_counts1 = svarstormvinga.groupby(pd.cut(svarstormvinga['Year'], bins=bins1), observed=True).size()

# Print the result
print(interval_counts1)
# Out:
# Year
# (1920, 1940]    2
# (1940, 1960]    1
# (1960, 1980]    2
# (1980, 2000]    4
# dtype: int64

# %%
print(svarstormvinga['Datum'].unique())
# Out:
# <DatetimeArray>
# ['1933-10-11 00:00:00', '1933-10-12 00:00:00', '1949-01-30 00:00:00',
#  '1969-09-22 00:00:00', '1969-09-29 00:00:00', '1981-11-24 00:00:00',
#  '1982-12-19 00:00:00', '1984-01-13 00:00:00', '1985-11-06 00:00:00']
# Length: 9, dtype: datetime64[ns]

# %%
print(orkanvinga['Datum'].unique())
# Out:
# <DatetimeArray>
# ['1976-01-05 00:00:00']
# Length: 1, dtype: datetime64[ns]

# %%
svarstormvinga
# Out:
#            Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 14193 1933-10-11  01:00:00         200.0        G           12.0          G
# 14198 1933-10-12  01:00:00         230.0        G           29.0          G
# 29272 1949-01-30  06:00:00         270.0        Y           14.0          Y
# 58241 1969-09-22  06:00:00         250.0        G           23.0          G
# 58276 1969-09-29  06:00:00         250.0        G           20.0          G
# 88378 1981-11-24  00:00:00         250.0        G           19.0          G
# 91497 1982-12-19  00:00:00         230.0        G           10.0          G
# 94616 1984-01-13  00:00:00         230.0        G           16.0          G
# 99919 1985-11-06  00:00:00         200.0        G           20.0          G
#
#        Year  Month  Snitt_per_dag  Max_uppmätta_hastighet
# 14193  1933     10          19.40                    30.0
# 14198  1933     10          16.80                    29.0
# 29272  1949      1          22.50                    29.5
# 58241  1969      9          23.80                    31.0
# 58276  1969      9          25.80                    30.0
# 88378  1981     11          22.25                    29.0
# 91497  1982     12          16.62                    30.0
# 94616  1984      1          24.38                    31.0
# 99919  1985     11          20.75                    30.0

# %%
orkanvinga
# Out:
#            Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 71192 1976-01-05  00:00:00         200.0        G           16.0          G
# 71193 1976-01-05  03:00:00         200.0        G           26.0          G
# 71194 1976-01-05  06:00:00         180.0        G           36.0          G
# 71195 1976-01-05  09:00:00         230.0        G           16.0          G
# 71196 1976-01-05  12:00:00         340.0        G           20.0          G
# 71197 1976-01-05  15:00:00         360.0        G           27.0          G
# 71198 1976-01-05  18:00:00         360.0        G           27.0          G
# 71199 1976-01-05  21:00:00         360.0        G           21.0          G
#
#        Year  Month  Snitt_per_dag  Max_uppmätta_hastighet
# 71192  1976      1          23.62                    36.0
# 71193  1976      1          23.62                    36.0
# 71194  1976      1          23.62                    36.0
# 71195  1976      1          23.62                    36.0
# 71196  1976      1          23.62                    36.0
# 71197  1976      1          23.62                    36.0
# 71198  1976      1          23.62                    36.0
# 71199  1976      1          23.62                    36.0
