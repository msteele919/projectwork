# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wind_gbg = pd.read_pickle('../Dataframes/df_wind_gbg.pkl')
wind_save = pd.read_pickle('../Dataframes/df_wind_save.pkl')
wind_vinga = pd.read_pickle('../Dataframes/df_wind_vinga.pkl')

# %%
plt.figure()
sns.lineplot(wind_gbg, x='Datum', y='Max_uppmätta_hastighet')
# Out:
# <Axes: xlabel='Datum', ylabel='Max_uppmätta_hastighet'>

# %%
plt.figure()
sns.lineplot(wind_save, x='Datum', y='Max_uppmätta_hastighet')
# Out:
# <Axes: xlabel='Datum', ylabel='Max_uppmätta_hastighet'>

# %%
plt.figure()
sns.lineplot(wind_vinga, x='Datum', y='Max_uppmätta_hastighet')
# Out:
# <Axes: xlabel='Datum', ylabel='Max_uppmätta_hastighet'>
