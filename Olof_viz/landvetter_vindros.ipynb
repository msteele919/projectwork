# %%
import pandas as pd
import matplotlib.pyplot as plt
import windrose as wr
import streamlit as st

# %%
df_landvetter = pd.read_csv('smhi_wind_landvetter.csv', usecols=[0, 1, 2, 3, 4, 5], header=8, sep=';')

# %%
df_landvetter
# Out:
#              Datum Tid (UTC)  Vindriktning Kvalitet  Vindhastighet Kvalitet.1
# 0       1977-10-03  01:00:00         150.0        Y            3.0          Y
# 1       1977-10-03  02:00:00         150.0        Y            3.0          Y
# 2       1977-10-03  04:00:00         140.0        Y            4.0          Y
# 3       1977-10-03  05:00:00         140.0        Y            4.0          Y
# 4       1977-10-03  07:00:00         130.0        Y            5.0          Y
# ...            ...       ...           ...      ...            ...        ...
# 271127  2023-08-01  02:00:00         120.0        G            3.0          G
# 271128  2023-08-01  03:00:00         120.0        G            2.0          G
# 271129  2023-08-01  04:00:00         100.0        G            2.0          G
# 271130  2023-08-01  05:00:00         100.0        G            3.0          G
# 271131  2023-08-01  06:00:00         110.0        G            3.0          G
#
# [271132 rows x 6 columns]

# %%
ax = wr.WindroseAxes.from_ax()
ax.bar(df_landvetter['Vindriktning'], df_landvetter['Vindhastighet'], normed=True)
ax.legend()
plt.show()

# %%
lon = 57.666
lat = 12.299
df_landvetter = pd.DataFrame({'LON': [lon], 'LAT': [lat]})
df_landvetter
# Out:
#       LON     LAT
# 0  57.666  12.299
