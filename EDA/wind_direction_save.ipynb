# %%
import pandas as pd
import windrose as wr
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_save = pd.read_pickle('../Dataframes/df_wind_save.pkl')

# %%
df_save
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1951-01-01  00:00:00         100.0        G            3.0          G
# 1      1951-01-01  03:00:00         110.0        G            2.0          G
# 2      1951-01-01  06:00:00          70.0        G            2.0          G
# 3      1951-01-01  12:00:00          90.0        G            3.0          G
# 4      1951-01-01  15:00:00          70.0        G            4.0          G
# ...           ...       ...           ...      ...            ...        ...
# 430417 2006-12-05  09:00:00         190.0        G            8.0          G
# 430418 2006-12-05  10:00:00         190.0        Y            8.0          Y
# 430419 2006-12-05  11:00:00         200.0        Y            9.0          Y
# 430420 2006-12-05  12:00:00         200.0        G           11.0          G
# 430421 2006-12-05  13:00:00         190.0        Y           10.0          Y
#
# ...

# %%
df_save = df_save.dropna().reset_index()
df_save = df_save.drop(columns=('index'))

# %%
df_save
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1951-01-01  00:00:00         100.0        G            3.0          G
# 1      1951-01-01  03:00:00         110.0        G            2.0          G
# 2      1951-01-01  06:00:00          70.0        G            2.0          G
# 3      1951-01-01  12:00:00          90.0        G            3.0          G
# 4      1951-01-01  15:00:00          70.0        G            4.0          G
# ...           ...       ...           ...      ...            ...        ...
# 430369 2006-12-05  09:00:00         190.0        G            8.0          G
# 430370 2006-12-05  10:00:00         190.0        Y            8.0          Y
# 430371 2006-12-05  11:00:00         200.0        Y            9.0          Y
# 430372 2006-12-05  12:00:00         200.0        G           11.0          G
# 430373 2006-12-05  13:00:00         190.0        Y           10.0          Y
#
# ...

# %%
df2_save = df_save[(df_save['Vindriktning'] >= 90) & (df_save['Vindriktning'] <= 180)]

# %%
df2_save
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1951-01-01  00:00:00         100.0        G            3.0          G
# 1      1951-01-01  03:00:00         110.0        G            2.0          G
# 3      1951-01-01  12:00:00          90.0        G            3.0          G
# 8      1951-01-02  03:00:00          90.0        G            3.0          G
# 9      1951-01-02  06:00:00          90.0        G            3.0          G
# ...           ...       ...           ...      ...            ...        ...
# 430330 2006-12-03  18:00:00         170.0        G           11.0          G
# 430331 2006-12-03  19:00:00         170.0        Y            9.0          Y
# 430332 2006-12-03  20:00:00         170.0        Y           10.0          Y
# 430333 2006-12-03  21:00:00         180.0        G           10.0          G
# 430368 2006-12-05  08:00:00         180.0        Y            9.0          Y
#
# ...

# %%
df3_save = df_save[df_save['Vindriktning'] > 180]

# %%
df3_save
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 24     1951-01-04  12:00:00         320.0        G            2.0          G
# 25     1951-01-04  15:00:00         320.0        G            1.0          G
# 66     1951-01-10  12:00:00         200.0        G            3.0          G
# 73     1951-01-11  12:00:00         200.0        G            4.0          G
# 79     1951-01-12  06:00:00         200.0        G            8.0          G
# ...           ...       ...           ...      ...            ...        ...
# 430369 2006-12-05  09:00:00         190.0        G            8.0          G
# 430370 2006-12-05  10:00:00         190.0        Y            8.0          Y
# 430371 2006-12-05  11:00:00         200.0        Y            9.0          Y
# 430372 2006-12-05  12:00:00         200.0        G           11.0          G
# 430373 2006-12-05  13:00:00         190.0        Y           10.0          Y
#
# ...

# %%
df_northeast_save = df_save[df_save['Vindriktning'] <= 90]
len(df_northeast_save)
# Out:
# 125408

# %%
df_southeast_save = df_save[(df_save['Vindriktning'] > 90) & (df_save['Vindriktning'] <= 180)]
len(df_southeast_save)
# Out:
# 99034

# %%
df_southwest_save = df_save[(df_save['Vindriktning'] > 180) & (df_save['Vindriktning'] <= 270)]
len(df_southwest_save)
# Out:
# 145029

# %%
df_northeast_save = df_save[(df_save['Vindriktning'] > 270) & (df_save['Vindriktning'] <= 360)]
len(df_northeast_save)
# Out:
# 60903

# %%
ax = wr.WindroseAxes.from_ax()
ax.bar(df_save['Vindriktning'], df_save['Max_uppmätta_hastighet'])

# %%
df_save['Vindriktning'].value_counts()
# Out:
# Vindriktning
# 0.0      33192
# 270.0    21859
# 200.0    20514
# 180.0    17929
# 210.0    17761
# 190.0    15755
# 220.0    14855
# 260.0    14820
# 280.0    14769
# 250.0    14563
# 230.0    13400
# 30.0     12148
# 50.0     12101
# 40.0     11990
# 240.0    11502
# 90.0     11001
# 170.0    10845
# 20.0     10715
# 120.0    10522
# 140.0    10440
# 60.0     10381
# 130.0    10349
# 110.0    10341
# 160.0    10320
# 70.0      9897
# 100.0     9213
# 150.0     9075
# 290.0     8791
# 360.0     8363
# 10.0      7023
# 80.0      6960
# 300.0     5811
# 320.0     5255
# 350.0     4741
# 310.0     4629
# 340.0     4450
# 330.0     4094
# Name: count, dtype: int64

# %%
ax = wr.WindroseAxes.from_ax()
ax.bar(df_save['Vindriktning'], df_save['Snitt_per_dag'], normed=True, opening=0.8)
plt.show()

# %%
df_save
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1951-01-01  00:00:00         100.0        G            3.0          G
# 1      1951-01-01  03:00:00         110.0        G            2.0          G
# 2      1951-01-01  06:00:00          70.0        G            2.0          G
# 3      1951-01-01  12:00:00          90.0        G            3.0          G
# 4      1951-01-01  15:00:00          70.0        G            4.0          G
# ...           ...       ...           ...      ...            ...        ...
# 430369 2006-12-05  09:00:00         190.0        G            8.0          G
# 430370 2006-12-05  10:00:00         190.0        Y            8.0          Y
# 430371 2006-12-05  11:00:00         200.0        Y            9.0          Y
# 430372 2006-12-05  12:00:00         200.0        G           11.0          G
# 430373 2006-12-05  13:00:00         190.0        Y           10.0          Y
#
# ...

# %%
df_save_pre_1987 = df_save[df_save['Year'] < 1987]
df_save_post_1987 = df_save[df_save['Year'] >= 1987]

# %%
ax = wr.WindroseAxes.from_ax()
ax.bar(df_save_pre_1987['Vindriktning'], df_save_pre_1987['Snitt_per_dag'], normed=True, opening=0.8)
plt.title('Wind directions and speeds, Pre 1987')
ax.legend()
plt.show()
ax = wr.WindroseAxes.from_ax()
ax.bar(df_save_post_1987['Vindriktning'], df_save_post_1987['Snitt_per_dag'], normed=True, opening=0.8)
plt.title('Wind Directions and speeds, 1987 ->')
ax.legend()
plt.show()

# %% [markdown]
# Let's look at an even earlier cutoff
# GBG station did only meassure N, NW, W, SW, S and so on undtil the 70's
# But Säve seems to be more detailed even before that

# %%
df_save_pre_1960 = df_save[df_save['Year'] < 1960]
df_save_post_1960 = df_save[df_save['Year'] >= 1960]

# %%
ax = wr.WindroseAxes.from_ax()
ax.bar(df_save_pre_1960['Vindriktning'], df_save_pre_1960['Snitt_per_dag'], normed=True, opening=0.8)
plt.title('Wind directions and speeds, Pre 1960')
ax.legend()
plt.show()
ax = wr.WindroseAxes.from_ax()
ax.bar(df_save_post_1960['Vindriktning'], df_save_post_1960['Snitt_per_dag'], normed=True, opening=0.8)
plt.title('Wind Directions and speeds, 1960 ->')
ax.legend()
plt.show()

# %% [markdown]
# Let's look at gbg

# %%
df_gbg = pd.read_pickle('../Dataframes/df_wind_gbg.pkl')

# %%
df_gbg
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1961-01-01  06:00:00         180.0        G            0.0          G
# 1      1961-01-01  12:00:00         180.0        G            4.0          G
# 2      1961-01-01  18:00:00         140.0        G            3.0          G
# 3      1961-01-02  06:00:00         180.0        G            4.0          G
# 4      1961-01-02  12:00:00         180.0        G            5.0          G
# ...           ...       ...           ...      ...            ...        ...
# 305146 2023-07-01  02:00:00         249.0        G            3.1          G
# 305147 2023-07-01  03:00:00         226.0        G            2.2          G
# 305148 2023-07-01  04:00:00         223.0        G            2.3          G
# 305149 2023-07-01  05:00:00         217.0        G            1.9          G
# 305150 2023-07-01  06:00:00         211.0        G            1.4          G
#
# ...

# %%
ax = wr.WindroseAxes.from_ax()
ax.bar(df_gbg['Vindriktning'], df_gbg['Max_uppmätta_hastighet'], normed=True)
ax.legend()
plt.show()

# %% [markdown]
# Let's look only on more powerful winds

# %%
# Storm speeds 
# Hård vind = 13.9

df_storm_save = df_save[df_save['Max_uppmätta_hastighet'] >= 13.9]
df_save_storm_pre_1987 = df_save_pre_1987[df_save_pre_1987['Vindhastighet'] >= 13.9]
df_save_storm_post_1987 = df_save_post_1987[df_save_post_1987['Vindhastighet'] >= 13.9]

# %%
df_storm_save

# %%
# plt.subplots(2, 1)
ax = wr.WindroseAxes.from_ax(figsize=(5, 5))
ax.bar(df_save_storm_pre_1987['Vindriktning'], df_save_storm_pre_1987['Max_uppmätta_hastighet'], opening=0.8)
plt.title(f'{len(df_save_storm_pre_1987)} observationer före 1987, Säve')
ax.legend()

# plt.subplots(2, 1)
ax = wr.WindroseAxes.from_ax(figsize=(5, 5))
ax.bar(df_save_storm_post_1987['Vindriktning'], df_save_storm_post_1987['Max_uppmätta_hastighet'], opening=0.8)
plt.title(f'{len(df_save_storm_post_1987)} observationer från 1987, Säve')
ax.legend()
plt.show()

# %% [markdown]
# Let's look at powerfull winds in GBG

# %%
df_gbg
# Out:
#             Datum   Tid_UTC  Vindriktning Kvalitet  Vindhastighet Kvalitet_1  \
# 0      1961-01-01  06:00:00         180.0        G            0.0          G
# 1      1961-01-01  12:00:00         180.0        G            4.0          G
# 2      1961-01-01  18:00:00         140.0        G            3.0          G
# 3      1961-01-02  06:00:00         180.0        G            4.0          G
# 4      1961-01-02  12:00:00         180.0        G            5.0          G
# ...           ...       ...           ...      ...            ...        ...
# 305146 2023-07-01  02:00:00         249.0        G            3.1          G
# 305147 2023-07-01  03:00:00         226.0        G            2.2          G
# 305148 2023-07-01  04:00:00         223.0        G            2.3          G
# 305149 2023-07-01  05:00:00         217.0        G            1.9          G
# 305150 2023-07-01  06:00:00         211.0        G            1.4          G
#
# ...

# %% [markdown]
# From 1961 until 2023, halfway point is 1992

# %%
2023-((2023-1961) / 2)
# Out:
# 1992.0

# %%
df_storm_gbg = df_gbg[df_gbg['Max_uppmätta_hastighet'] >= 13.9]
df_storm_gbg_pre_1992 = df_storm_gbg[df_storm_gbg['Year'] < 1992]
# df_storm_gbg_pre_1992 = df_storm_gbg_pre_1992[df_storm_gbg_pre_1992['Year'] == 1961]
df_storm_gbg_post_1992 = df_storm_gbg[df_storm_gbg['Year'] >= 1992]

# %%
ax = wr.WindroseAxes.from_ax(figsize=(5, 5))
ax.bar(df_storm_gbg_pre_1992['Vindriktning'], df_storm_gbg_pre_1992['Max_uppmätta_hastighet'], opening=0.8)
plt.title(f'{len(df_storm_gbg_pre_1992)} observationer före 1992, GBG')
ax.legend()
plt.show()
ax = wr.WindroseAxes.from_ax(figsize=(5, 5))
ax.bar(df_storm_gbg_post_1992['Vindriktning'], df_storm_gbg_post_1992['Max_uppmätta_hastighet'], opening=0.8)
plt.title(f'{len(df_storm_gbg_post_1992)} observationer från 1992, GBG')
ax.legend()
plt.show()

# %%
over_20_pre_1992 = len(df_storm_gbg_pre_1992[df_storm_gbg_pre_1992['Max_uppmätta_hastighet'] > 20])
over_20_post_1992 = len(df_storm_gbg_post_1992[df_storm_gbg_post_1992['Max_uppmätta_hastighet'] > 20])

# %%
kat_7_gbg_pre_1992 = len(df_storm_gbg_pre_1992[df_storm_gbg_pre_1992['Max_uppmätta_hastighet'] >= 13.9])
kat_8_gbg_pre_1992 = len(df_storm_gbg_pre_1992[df_storm_gbg_pre_1992['Max_uppmätta_hastighet'] >= 17.2])
kat_9_gbg_pre_1992 = len(df_storm_gbg_pre_1992[df_storm_gbg_pre_1992['Max_uppmätta_hastighet'] >= 20.8])
kat_10_gbg_pre_1992 = len(df_storm_gbg_pre_1992[df_storm_gbg_pre_1992['Max_uppmätta_hastighet'] >= 25.5])
kat_11_gbg_pre_1992 = len(df_storm_gbg_pre_1992[df_storm_gbg_pre_1992['Max_uppmätta_hastighet'] >= 28.5])
kat_12_gbg_pre_1992 = len(df_storm_gbg_pre_1992[df_storm_gbg_pre_1992['Max_uppmätta_hastighet'] >= 32.7])

intensity_pre_1992_gbg = [kat_7_gbg_pre_1992, kat_8_gbg_pre_1992, kat_9_gbg_pre_1992, kat_10_gbg_pre_1992, kat_11_gbg_pre_1992, kat_12_gbg_pre_1992]

# %%
kat_7_gbg_post_1992 = len(df_storm_gbg_post_1992[df_storm_gbg_post_1992['Max_uppmätta_hastighet'] >= 13.9])
kat_8_gbg_post_1992 = len(df_storm_gbg_post_1992[df_storm_gbg_post_1992['Max_uppmätta_hastighet'] >= 17.2])
kat_9_gbg_post_1992 = len(df_storm_gbg_post_1992[df_storm_gbg_post_1992['Max_uppmätta_hastighet'] >= 20.8])
kat_10_gbg_post_1992 = len(df_storm_gbg_post_1992[df_storm_gbg_post_1992['Max_uppmätta_hastighet'] >= 25.5])
kat_11_gbg_post_1992 = len(df_storm_gbg_post_1992[df_storm_gbg_post_1992['Max_uppmätta_hastighet'] >= 28.5])
kat_12_gbg_post_1992 = len(df_storm_gbg_post_1992[df_storm_gbg_post_1992['Max_uppmätta_hastighet'] >= 32.7])

intensity_post_1992_gbg = [kat_7_gbg_post_1992, kat_8_gbg_post_1992, kat_9_gbg_post_1992, kat_10_gbg_post_1992, kat_11_gbg_post_1992, kat_12_gbg_post_1992]

# %%
df_hard_wind_gbg = pd.DataFrame({'Categories': ['>13.9 m/s', '>17.2 m/s', '>20.8 m/s', '>25.5 m/s', '>28.5 m/s', '>32.7 m/s'], 'Values_pre_1992': intensity_pre_1992_gbg, 'Values_post_1992': intensity_post_1992_gbg})
# df_post_1992 = pd.DataFrame({'Categories': ['7', '8', '9', '10', '11', '12'], 'Values': intensity_post_1992})

# %%
plt.figure()
plt.title('Hårda vindar i Göteborg')
sns.barplot(x=df_hard_wind_gbg['Categories'], y=df_hard_wind_gbg['Values_pre_1992'])
sns.barplot(x=df_hard_wind_gbg['Categories'], y=df_hard_wind_gbg['Values_post_1992'])

plt.ylabel('Antal mätningar')
plt.xlabel('SMHI kategorier')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Säve

# %%
kat_7_save_pre_1987 = len(df_save_storm_pre_1987[df_save_storm_pre_1987['Max_uppmätta_hastighet'] >= 13.9])
kat_8_save_pre_1987 = len(df_save_storm_pre_1987[df_save_storm_pre_1987['Max_uppmätta_hastighet'] >= 17.2])
kat_9_save_pre_1987 = len(df_save_storm_pre_1987[df_save_storm_pre_1987['Max_uppmätta_hastighet'] >= 20.8])
kat_10_save_pre_1987 = len(df_save_storm_pre_1987[df_save_storm_pre_1987['Max_uppmätta_hastighet'] >= 25.5])
kat_11_save_pre_1987 = len(df_save_storm_pre_1987[df_save_storm_pre_1987['Max_uppmätta_hastighet'] >= 28.5])
kat_12_save_pre_1987 = len(df_save_storm_pre_1987[df_save_storm_pre_1987['Max_uppmätta_hastighet'] >= 32.7])

intensity_pre_1987_save = [kat_7_save_pre_1987, kat_8_save_pre_1987, kat_9_save_pre_1987, kat_10_save_pre_1987, kat_11_save_pre_1987, kat_12_save_pre_1987]

kat_7_save_post_1987 = len(df_save_storm_post_1987[df_save_storm_post_1987['Max_uppmätta_hastighet'] >= 13.9])
kat_8_save_post_1987 = len(df_save_storm_post_1987[df_save_storm_post_1987['Max_uppmätta_hastighet'] >= 17.2])
kat_9_save_post_1987 = len(df_save_storm_post_1987[df_save_storm_post_1987['Max_uppmätta_hastighet'] >= 20.8])
kat_10_save_post_1987 = len(df_save_storm_post_1987[df_save_storm_post_1987['Max_uppmätta_hastighet'] >= 25.5])
kat_11_save_post_1987 = len(df_save_storm_post_1987[df_save_storm_post_1987['Max_uppmätta_hastighet'] >= 28.5])
kat_12_save_post_1987 = len(df_save_storm_post_1987[df_save_storm_post_1987['Max_uppmätta_hastighet'] >= 32.7])

intensity_post_1987_save = [kat_7_save_post_1987, kat_8_save_post_1987, kat_9_save_post_1987, kat_10_save_post_1987, kat_11_save_post_1987, kat_12_save_post_1987]

# %%
df_hard_wind_save = pd.DataFrame({'Categories': ['>13.9 m/s', '>17.2 m/s', '>20.8 m/s', '>25.5 m/s', '>28.5 m/s', '>32.7 m/s'], 'Values_pre_1987': intensity_pre_1987_save, 'Values_post_1987': intensity_post_1987_save})

# %%
plt.figure()
plt.title('Hårda vindar i Säve')
sns.barplot(x=df_hard_wind_save['Categories'], y=df_hard_wind_save['Values_pre_1987'])
sns.barplot(x=df_hard_wind_save['Categories'], y=df_hard_wind_save['Values_post_1987'])

plt.ylabel('Antal mätningar')
plt.xlabel('SMHI kategorier')
plt.show()

# %% [markdown]
# The following is just tests

# %%
# rose_test_directions = [0, 0, 0, 0, 90, 90, 180, 180, 180, 270, 270, 270]
# rose_test_speeds =  [1, 100, 150, 1, 100, 150, 1, 100, 150, 1, 100, 150]

# %%
# Färgen är värdet, i det här fallet vindhastigheten.Ju mörkare(längre in) desto lägre värde
# Hur långt de når är hur många observationer
# Anges i procent. 

# ax = wr.WindroseAxes.from_ax()
# ax.bar(rose_test_directions, rose_test_speeds, normed=True, opening=0.8)
# plt.title('Wind Directions, 1970 ->')
# ax.legend()
# plt.show()

# %%
# rose_test_df = pd.DataFrame(data={'Directions': rose_test_directions, 'Speed': rose_test_speeds})

# %%
# rose_test_df
