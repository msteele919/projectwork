# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_daily_temp_save = pd.read_pickle('../Dataframes/df_daily_temp_save.pkl')
df_daily_temp_save

# %%
df_daily_temp_save.describe()
# Out:
#                      Datum  Snittemperatur          Year         Month
# count                22985    22985.000000  22985.000000  22985.000000
# mean   1975-06-19 00:00:00        7.481740   1974.964238      6.516685
# min    1944-01-01 00:00:00      -21.700000   1944.000000      1.000000
# 25%    1959-09-25 00:00:00        1.970000   1959.000000      4.000000
# 50%    1975-06-19 00:00:00        7.440000   1975.000000      7.000000
# 75%    1991-03-13 00:00:00       13.780000   1991.000000     10.000000
# max    2006-12-05 00:00:00       28.600000   2006.000000     12.000000
# std                    NaN        7.437473     18.165184      3.445816

# %%
df_daily_temp_save.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22985 entries, 0 to 22984
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Datum           22985 non-null  datetime64[ns]
#  1   Kvalitet        22985 non-null  object
#  2   Snittemperatur  22985 non-null  float64
#  3   Year            22985 non-null  int32
#  4   Month           22985 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(1)
# memory usage: 718.4+ KB

# %%
plt.figure(figsize=(15, 8)) 

plt.scatter(x=df_daily_temp_save['Datum'], y=df_daily_temp_save['Snittemperatur'])
plt.title('Daily temp, Säve')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_daily_temp_gbg = pd.read_pickle('../Dataframes/df_daily_temp_gbg.pkl')
df_daily_temp_gbg
# Out:
#            Datum Kvalitet  Snittemperatur  Year  Month
# 0     1961-01-01        G            1.07  1961      1
# 1     1961-01-02        G            2.27  1961      1
# 2     1961-01-03        G            2.27  1961      1
# 3     1961-01-04        G            2.53  1961      1
# 4     1961-01-05        G            2.13  1961      1
# ...          ...      ...             ...   ...    ...
# 19909 2023-06-27        G           18.18  2023      6
# 19910 2023-06-28        G           19.72  2023      6
# 19911 2023-06-29        G           19.22  2023      6
# 19912 2023-06-30        G           17.40  2023      6
# 19913 2023-07-01        G           16.06  2023      7
#
# [19914 rows x 5 columns]

# %%
df_daily_temp_gbg.describe()
# Out:
#                                Datum  Snittemperatur          Year  \
# count                          19914    19914.000000  19914.000000
# mean   1993-08-29 12:00:17.354624896        8.608544   1993.163955
# min              1961-01-01 00:00:00      -22.220000   1961.000000
# 25%              1974-11-03 06:00:00        3.172500   1974.000000
# 50%              1995-02-03 12:00:00        8.500000   1995.000000
# 75%              2009-10-13 18:00:00       14.710000   2009.000000
# max              2023-07-01 00:00:00       27.230000   2023.000000
# std                              NaN        7.337632     18.696410
#
#               Month
# count  19914.000000
# mean       6.485940
# min        1.000000
# 25%        3.000000
# 50%        6.000000
# 75%        9.000000
# max       12.000000
# std        3.446535

# %%
df_daily_temp_gbg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19914 entries, 0 to 19913
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Datum           19914 non-null  datetime64[ns]
#  1   Kvalitet        19914 non-null  object
#  2   Snittemperatur  19914 non-null  float64
#  3   Year            19914 non-null  int32
#  4   Month           19914 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(1)
# memory usage: 622.4+ KB

# %%
plt.figure(figsize=(15, 8)) 

plt.scatter(x=df_daily_temp_gbg['Datum'], y=df_daily_temp_gbg['Snittemperatur'])
plt.title('Daily temp, GBG')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_daily_temp_gbg_save_adjusted = pd.read_pickle('../Dataframes/daily_temp_gbg_save_adjusted.pkl')

# %%
df_daily_temp_gbg_save_adjusted.describe()
# Out:
#                                Datum  Snittemperatur         Month  \
# count                          29114    29114.000000  29114.000000
# mean   1983-11-12 04:26:08.894689792        8.068100      6.505049
# min              1944-01-01 00:00:00      -21.700000      1.000000
# 25%              1963-12-05 06:00:00        2.580000      4.000000
# 50%              1983-11-08 12:00:00        8.080000      7.000000
# 75%              2003-10-12 18:00:00       14.260000      9.000000
# max              2023-10-16 00:00:00       28.600000     12.000000
# std                              NaN        7.492887      3.441977
#
#                Year   Day_of_year  Over_10_5_days_in_a_row
# count  29114.000000  29114.000000             29114.000000
# mean    1983.365460    182.575908                 0.076389
# min     1944.000000      1.000000                 0.000000
# 25%     1963.000000     91.000000                 0.000000
# 50%     1983.000000    182.000000                 0.000000
# ...

# %%
df_daily_temp_gbg_save_adjusted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29114 entries, 0 to 29113
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Datum                    29114 non-null  datetime64[ns]
#  1   Kvalitet                 29114 non-null  object
#  2   Snittemperatur           29114 non-null  float64
#  3   Month                    29114 non-null  int32
#  4   Year                     29114 non-null  int32
#  5   Day_of_year              29114 non-null  int32
#  6   Over_10_5_days_in_a_row  29114 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int32(3), int64(1), object(1)
# memory usage: 1.2+ MB

# %%
plt.figure(figsize=(15, 8)) 

plt.scatter(x=df_daily_temp_gbg_save_adjusted['Datum'], y=df_daily_temp_gbg_save_adjusted['Snittemperatur'])
plt.title('Daily temp, Säve and GBG')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Precipitation

# %%
df_daily_prec_save = pd.read_pickle('../Dataframes/df_daily_precipitation_save.pkl')
df_daily_prec_save
# Out:
#            Datum  Nederbördsmängd Kvalitet  Year  Month
# 0     1944-01-01              0.2        G  1944      1
# 1     1944-01-02              0.4        G  1944      1
# 2     1944-01-03              0.0        G  1944      1
# 3     1944-01-04              0.0        G  1944      1
# 4     1944-01-05              2.1        G  1944      1
# ...          ...              ...      ...   ...    ...
# 21514 2002-11-26              4.1        G  2002     11
# 21515 2002-11-27              0.0        G  2002     11
# 21516 2002-11-28              3.9        G  2002     11
# 21517 2002-11-29              7.1        G  2002     11
# 21518 2002-11-30              5.0        G  2002     11
#
# [21519 rows x 5 columns]

# %%
df_daily_prec_save.describe()
# Out:
#                      Datum  Nederbördsmängd          Year         Month
# count                21519     21519.000000  21519.000000  21519.000000
# mean   1973-06-16 00:00:00         2.112291   1972.957526      6.514987
# min    1944-01-01 00:00:00         0.000000   1944.000000      1.000000
# 25%    1958-09-23 12:00:00         0.000000   1958.000000      4.000000
# 50%    1973-06-16 00:00:00         0.000000   1973.000000      7.000000
# 75%    1988-03-08 12:00:00         2.000000   1988.000000     10.000000
# max    2002-11-30 00:00:00        57.000000   2002.000000     12.000000
# std                    NaN         4.473545     17.006605      3.445005

# %%
df_daily_prec_save.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21519 entries, 0 to 21518
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Datum            21519 non-null  datetime64[ns]
#  1   Nederbördsmängd  21519 non-null  float64
#  2   Kvalitet         21519 non-null  object
#  3   Year             21519 non-null  int32
#  4   Month            21519 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(1)
# memory usage: 672.6+ KB

# %%
plt.figure(figsize=(15, 8)) 

plt.scatter(x=df_daily_prec_save['Datum'], y=df_daily_prec_save['Nederbördsmängd'])
plt.title('Daily precipitation, Save')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_daily_prec_gbg = pd.read_pickle('../Dataframes/df_daily_precipitation_gbg.pkl')
df_daily_prec_gbg
# Out:
#            Datum  Nederbördsmängd Kvalitet  Year  Month
# 0     1961-01-01              0.3        Y  1961      1
# 1     1961-01-02              0.5        Y  1961      1
# 2     1961-01-03              8.4        Y  1961      1
# 3     1961-01-04              0.0        Y  1961      1
# 4     1961-01-05              2.0        Y  1961      1
# ...          ...              ...      ...   ...    ...
# 15487 2023-06-26             18.5        G  2023      6
# 15488 2023-06-27             10.6        G  2023      6
# 15489 2023-06-28              0.0        G  2023      6
# 15490 2023-06-29              5.0        G  2023      6
# 15491 2023-06-30              0.2        G  2023      6
#
# [15492 rows x 5 columns]

# %%
df_daily_prec_gbg.describe()
# Out:
#                                Datum  Nederbördsmängd          Year  \
# count                          15492     15492.000000  15492.000000
# mean   1995-01-12 22:19:53.493415936         2.341112   1994.536406
# min              1961-01-01 00:00:00         0.000000   1961.000000
# 25%              1971-10-09 18:00:00         0.000000   1971.000000
# 50%              2002-04-15 12:00:00         0.000000   2002.000000
# 75%              2012-11-21 06:00:00         2.400000   2012.000000
# max              2023-06-30 00:00:00        85.700000   2023.000000
# std                              NaN         4.856172     20.908330
#
#               Month
# count  15492.000000
# mean       6.490382
# min        1.000000
# 25%        3.000000
# 50%        7.000000
# 75%        9.000000
# max       12.000000
# std        3.456729

# %%
df_daily_prec_gbg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15492 entries, 0 to 15491
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Datum            15492 non-null  datetime64[ns]
#  1   Nederbördsmängd  15492 non-null  float64
#  2   Kvalitet         15492 non-null  object
#  3   Year             15492 non-null  int32
#  4   Month            15492 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(1)
# memory usage: 484.2+ KB

# %%
plt.figure(figsize=(15, 8)) 

plt.scatter(x=df_daily_prec_gbg['Datum'], y=df_daily_prec_gbg['Nederbördsmängd'])
plt.title('Daily precipitation GBG')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_compiled_daily_prec_gbg_save = pd.read_pickle('../Dataframes/df_compiled_daily_precipitation_gbg_save.pkl')
df_compiled_daily_prec_gbg_save
# Out:
#            Datum  Nederbördsmängd Kvalitet  Year  Month  \
# 0     1944-01-01              0.2        G  1944      1
# 1     1944-01-02              0.4        G  1944      1
# 2     1944-01-03              0.0        G  1944      1
# 3     1944-01-04              0.0        G  1944      1
# 4     1944-01-05              2.1        G  1944      1
# ...          ...              ...      ...   ...    ...
# 15487 2023-06-26             18.5        G  2023      6
# 15488 2023-06-27             10.6        G  2023      6
# 15489 2023-06-28              0.0        G  2023      6
# 15490 2023-06-29              5.0        G  2023      6
# 15491 2023-06-30              0.2        G  2023      6
#
#        Avg_nederbörd_per_dag  Max_uppmätta_nederbörd
# 0                       2.70                    16.6
# 1                       2.70                    16.6
# 2                       2.70                    16.6
# 3                       2.70                    16.6
# ...

# %%
df_compiled_daily_prec_gbg_save.describe()
# Out:
#                      Datum  Nederbördsmängd          Year         Month  \
# count                29036     29036.000000  29036.000000  29036.000000
# mean   1983-09-30 12:00:00         2.232401   1983.248657      6.504098
# min    1944-01-01 00:00:00         0.000000   1944.000000      1.000000
# 25%    1963-11-15 18:00:00         0.000000   1963.000000      4.000000
# 50%    1983-09-30 12:00:00         0.000000   1983.000000      7.000000
# 75%    2003-08-15 06:00:00         2.200000   2003.000000     10.000000
# max    2023-06-30 00:00:00        59.700000   2023.000000     12.000000
# std                    NaN         4.672588     22.949893      3.448829
#
#        Avg_nederbörd_per_dag  Max_uppmätta_nederbörd
# count           29036.000000            29036.000000
# mean                2.232365               17.366879
# min                 0.000000                0.000000
# 25%                 1.280000               11.100000
# ...

# %%
df_compiled_daily_prec_gbg_save.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29036 entries, 0 to 15491
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Datum                   29036 non-null  datetime64[ns]
#  1   Nederbördsmängd         29036 non-null  float64
#  2   Kvalitet                29036 non-null  object
#  3   Year                    29036 non-null  int32
#  4   Month                   29036 non-null  int32
#  5   Avg_nederbörd_per_dag   29036 non-null  float64
#  6   Max_uppmätta_nederbörd  29036 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int32(2), object(1)
# memory usage: 1.6+ MB

# %%
plt.figure(figsize=(15, 8)) 

plt.scatter(x=df_compiled_daily_prec_gbg_save['Datum'], y=df_compiled_daily_prec_gbg_save['Nederbördsmängd'])
plt.title('Daily precipitation GBG')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_compiled_monthly_prec_gbg_save = pd.read_pickle('../Dataframes/df_compiled_monthly_precipitation_gbg_save.pkl')
df_compiled_monthly_prec_gbg_save
# Out:
#      Year  Month Kvalitet  Avg_nederbörd_per_dag  Max_uppmätta_nederbörd
# 0    1944      1        G                   2.70                    16.6
# 1    1944      2        G                   0.69                     9.8
# 2    1944      3        G                   0.64                     4.0
# 3    1944      4        G                   1.20                    12.8
# 4    1944      5        G                   1.54                    10.0
# ..    ...    ...      ...                    ...                     ...
# 504  2023      2        G                   2.53                    19.1
# 505  2023      3        G                   3.99                    27.9
# 506  2023      4        G                   0.75                     8.7
# 507  2023      5        G                   0.46                     8.5
# 508  2023      6        G                   1.31                    18.5
#
# [954 rows x 5 columns]

# %%
df_compiled_monthly_prec_gbg_save.describe()
# Out:
#               Year       Month  Avg_nederbörd_per_dag  Max_uppmätta_nederbörd
# count   954.000000  954.000000             954.000000              954.000000
# mean   1983.251572    6.481132               2.229193               17.336164
# std      22.962619    3.453812               1.268283                8.945991
# min    1944.000000    1.000000               0.000000                0.000000
# 25%    1963.000000    3.000000               1.280000               11.100000
# 50%    1983.000000    6.000000               2.050000               16.000000
# 75%    2003.000000    9.000000               2.985000               21.775000
# max    2023.000000   12.000000               7.110000               59.700000

# %%
df_compiled_monthly_prec_gbg_save.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 954 entries, 0 to 508
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    954 non-null    int32
#  1   Month                   954 non-null    int32
#  2   Kvalitet                954 non-null    object
#  3   Avg_nederbörd_per_dag   954 non-null    float64
#  4   Max_uppmätta_nederbörd  954 non-null    float64
# dtypes: float64(2), int32(2), object(1)
# memory usage: 37.3+ KB

# %%
plt.figure(figsize=(15, 8)) 

plt.scatter(x=df_compiled_monthly_prec_gbg_save['Year'], y=df_compiled_monthly_prec_gbg_save['Avg_nederbörd_per_dag'])
sns.lineplot(x=df_compiled_monthly_prec_gbg_save['Year'], y=df_compiled_monthly_prec_gbg_save['Max_uppmätta_nederbörd'])
plt.title('Daily precipitation GBG')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_jan = pd.read_pickle('../dataframes/df_compiled_monthly_temp_gbg_save.pkl')

# %%
df_jan = df_jan[df_jan['Month'] == 1]
df_jan
# Out:
#      Year  Month  Snittemperatur
# 0    1944      1            2.03
# 12   1945      1           -2.03
# 24   1946      1           -0.98
# 36   1947      1           -3.81
# 48   1948      1           -2.38
# ..    ...    ...             ...
# 605  2019      1            0.44
# 617  2020      1            5.62
# 629  2021      1           -0.15
# 641  2022      1            3.54
# 653  2023      1            3.57
#
# [118 rows x 3 columns]

# %%
plt.figure
plt.scatter(x=df_jan['Year'], y=df_jan['Snittemperatur'])
