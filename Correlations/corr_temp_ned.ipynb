# %%
import pandas as pd 
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.stats.api as sms

# %% [markdown]
# # Import Data

# %% [markdown]
# temperature

# %%
df = pd.read_pickle('../Dataframes/df_compiled_daily_temp_gbg_save.pkl')

# %%
df
# Out:
#            Datum Kvalitet  Snittemperatur  Year  Month
# 0     1944-01-01        G            3.20  1944      1
# 1     1944-01-02        G            3.60  1944      1
# 2     1944-01-03        G            2.80  1944      1
# 3     1944-01-04        G           -4.47  1944      1
# 4     1944-01-05        G           -1.40  1944      1
# ...          ...      ...             ...   ...    ...
# 29002 2023-06-27        G           18.18  2023      6
# 29003 2023-06-28        G           19.72  2023      6
# 29004 2023-06-29        G           19.22  2023      6
# 29005 2023-06-30        G           17.40  2023      6
# 29006 2023-07-01        G           16.06  2023      7
#
# [29007 rows x 5 columns]

# %%
# check for missing values
yearly_day_counts = df.groupby('Year')['Datum'].count()

years_with_less_than_365 = yearly_day_counts[yearly_day_counts < 365]

print( years_with_less_than_365.index)
# Out:
# Index([2013, 2023], dtype='int32', name='Year')

# %%
# Filter the DataFrame for the year 2013
data_2013 = df[df['Year'] == 2013]

monthly_day_counts_2013 = data_2013.groupby(['Year', 'Month'])['Datum'].nunique()

# Find and print the months with fewer than 30 unique days
months_under_30 = monthly_day_counts_2013[monthly_day_counts_2013 < 30]

# Filter the DataFrame for the year 2013 and the specific date range
data_2013 = df[(df['Year'] == 2013) & (df['Datum'] >= '2013-12-02') & (df['Datum'] <= '2013-12-31')]

# Calculate the mean temperature for the entire dataset
imputed_data = pd.DataFrame(columns=['Datum', 'Snittemperatur'])

data_before_2013 = df[df['Year'] < 2013]

# Loop through the missing dates in December 2013
for date in pd.date_range(start='2013-12-02', end='2013-12-31'):
    # Calculate the mean temperature for the respective day in history
    mean_temperature = data_before_2013[data_before_2013['Datum'].dt.strftime('%m-%d') == date.strftime('%m-%d')]['Snittemperatur'].mean()
    imputed_data = pd.concat([imputed_data, pd.DataFrame({'Datum': [date], 'Snittemperatur': [mean_temperature]})], ignore_index=True)

df = df.set_index('Datum')
imputed_data = imputed_data.set_index('Datum')

df = pd.concat([df, imputed_data], axis=0)
df = df.sort_values(by='Datum', ascending=True)
df
# Out:
#            Kvalitet  Snittemperatur    Year  Month
# Datum
# 1944-01-01        G            3.20  1944.0    1.0
# 1944-01-02        G            3.60  1944.0    1.0
# 1944-01-03        G            2.80  1944.0    1.0
# 1944-01-04        G           -4.47  1944.0    1.0
# 1944-01-05        G           -1.40  1944.0    1.0
# ...             ...             ...     ...    ...
# 2023-06-27        G           18.18  2023.0    6.0
# 2023-06-28        G           19.72  2023.0    6.0
# 2023-06-29        G           19.22  2023.0    6.0
# 2023-06-30        G           17.40  2023.0    6.0
# 2023-07-01        G           16.06  2023.0    7.0
#
# [29037 rows x 4 columns]

# %%
df_reset = df.reset_index()

df_reset['Datum'] = pd.to_datetime(df_reset['Datum'])

monthly_temperature = df_reset.groupby(['Year', 'Month'])['Snittemperatur'].mean().reset_index()
monthly_temperature 

# monthly_avg_temperature = df.resample('M')['Snittemperatur'].mean().reset_index()

# Display the new DataFrame
# print(monthly_avg_temperature)
# Out:
#        Year  Month  Snittemperatur
# 0    1944.0    1.0        2.025484
# 1    1944.0    2.0        0.180345
# 2    1944.0    3.0        0.959032
# 3    1944.0    4.0        6.081333
# 4    1944.0    5.0       10.736774
# ..      ...    ...             ...
# 950  2023.0    3.0        2.388065
# 951  2023.0    4.0        8.061000
# 952  2023.0    5.0       13.518387
# 953  2023.0    6.0       18.590000
# 954  2023.0    7.0       16.060000
#
# [955 rows x 3 columns]

# %%
monthly_temperature['Year'] = monthly_temperature['Year'].astype(int)
monthly_temperature['Month'] = monthly_temperature['Month'].astype(int)

# %%
monthly_temperature
# Out:
#      Year  Month  Snittemperatur
# 0    1944      1        2.025484
# 1    1944      2        0.180345
# 2    1944      3        0.959032
# 3    1944      4        6.081333
# 4    1944      5       10.736774
# ..    ...    ...             ...
# 950  2023      3        2.388065
# 951  2023      4        8.061000
# 952  2023      5       13.518387
# 953  2023      6       18.590000
# 954  2023      7       16.060000
#
# [955 rows x 3 columns]

# %%
# drop the last month observation because it's not present in precipitation 
monthly_temperature = monthly_temperature.drop(954)

# %% [markdown]
# Percipitation

# %%
df2 = pd.read_pickle('../Dataframes/df_compiled_daily_precipitation_gbg_save.pkl')

# %%
df2
# Out:
#            Datum  Nederbördsmängd Kvalitet  Year  Month  \
# 0     1944-01-01              0.2        G  1944      1
# 1     1944-01-02              0.4        G  1944      1
# 2     1944-01-03              0.0        G  1944      1
# 3     1944-01-04              0.0        G  1944      1
# 4     1944-01-05              2.1        G  1944      1
# ...          ...              ...      ...   ...    ...
# 29031 2023-06-26             18.5        G  2023      6
# 29032 2023-06-27             10.6        G  2023      6
# 29033 2023-06-28              0.0        G  2023      6
# 29034 2023-06-29              5.0        G  2023      6
# 29035 2023-06-30              0.2        G  2023      6
#
#        Avg_nederbörd_per_dag  Max_uppmätta_nederbörd
# 0                       2.70                    16.6
# 1                       2.70                    16.6
# 2                       2.70                    16.6
# 3                       2.70                    16.6
# ...

# %%
# check for missing values
yearly_day_counts = df2.groupby('Year')['Datum'].count()

years_with_less_than_365 = yearly_day_counts[yearly_day_counts < 365]

print( years_with_less_than_365.index)
# Out:
# Index([2023], dtype='int32', name='Year')

# %%
df2
# Out:
#            Datum  Nederbördsmängd Kvalitet  Year  Month  \
# 0     1944-01-01              0.2        G  1944      1
# 1     1944-01-02              0.4        G  1944      1
# 2     1944-01-03              0.0        G  1944      1
# 3     1944-01-04              0.0        G  1944      1
# 4     1944-01-05              2.1        G  1944      1
# ...          ...              ...      ...   ...    ...
# 29031 2023-06-26             18.5        G  2023      6
# 29032 2023-06-27             10.6        G  2023      6
# 29033 2023-06-28              0.0        G  2023      6
# 29034 2023-06-29              5.0        G  2023      6
# 29035 2023-06-30              0.2        G  2023      6
#
#        Avg_nederbörd_per_dag  Max_uppmätta_nederbörd
# 0                       2.70                    16.6
# 1                       2.70                    16.6
# 2                       2.70                    16.6
# 3                       2.70                    16.6
# ...

# %%
new_df = df2.loc[[0,32]]
print(new_df)
# Out:
#         Datum  Nederbördsmängd Kvalitet  Year  Month  Avg_nederbörd_per_dag  \
# 0  1944-01-01              0.2        G  1944      1                   2.70
# 32 1944-02-02              2.0        G  1944      2                   0.69
#
#     Max_uppmätta_nederbörd
# 0                     16.6
# 32                     9.8

# %%
df2['Datum'] = pd.to_datetime(df2['Datum'])

# Group the data by 'Year' and 'Month' and calculate the sum of 'Nederbördsmängd' for each group
# monthly_precipitation = df2.groupby(['Year', 'Month'])['Nederbördsmängd'].sum().reset_index()
monthly_precipitation = df2.groupby(['Year', 'Month']).agg({'Nederbördsmängd': 'sum', 'Max_uppmätta_nederbörd': 'max'}).reset_index()

# Rename the columns for clarity
monthly_precipitation.columns = ['Year', 'Month', 'Total_Nederbördsmängd', 'Max_uppmätta_nederbörd']

# Display the new DataFrame
monthly_precipitation
# Out:
#      Year  Month  Total_Nederbördsmängd  Max_uppmätta_nederbörd
# 0    1944      1                   83.6                    16.6
# 1    1944      2                   19.9                     9.8
# 2    1944      3                   19.7                     4.0
# 3    1944      4                   36.1                    12.8
# 4    1944      5                   47.7                    10.0
# ..    ...    ...                    ...                     ...
# 949  2023      2                   70.8                    19.1
# 950  2023      3                  123.8                    27.9
# 951  2023      4                   22.6                     8.7
# 952  2023      5                   14.3                     8.5
# 953  2023      6                   39.2                    18.5
#
# [954 rows x 4 columns]

# %% [markdown]
# ## Summary Statistics

# %%
summary_temperature = monthly_temperature['Snittemperatur'].describe()

# Calculate summary statistics for 'Total_Nederbördsmängd' in df2
summary_precipitation = monthly_precipitation['Total_Nederbördsmängd'].describe()

# Combine the summary statistics into a single DataFrame
summary_table = pd.concat([summary_temperature, summary_precipitation], axis=1)
summary_table.columns = ['Snittemperatur', 'Total_Nederbördsmängd']

print(summary_table)
# Out:
#        Snittemperatur  Total_Nederbördsmängd
# count      954.000000             954.000000
# mean         7.804302              67.945493
# std          6.805783              38.856142
# min        -10.380000               0.000000
# 25%          2.182025              38.875000
# 50%          7.559500              62.250000
# 75%         13.924083              90.700000
# max         21.365484             220.300000

# %%
#historgram with monthly snittemperatur 
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(monthly_temperature['Snittemperatur'], bins=20, color='lightblue', edgecolor='black')
plt.title('Histogram: Genomsnittlig månadstemperatur')

plt.ylabel('Freqvens')

# histogram with monthly total precipitation 
plt.subplot(1, 2, 2)
plt.hist(monthly_precipitation['Total_Nederbördsmängd'], bins=20, color='lightcoral', edgecolor='black')
plt.title('Histogram: Total månatlig nederbörd')

plt.ylabel('Freqvens')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(monthly_precipitation['Year'], monthly_precipitation['Total_Nederbördsmängd'], color='blue', alpha=0.5)
plt.title('Monthly Total Percipitation')
plt.xlabel('Year')
plt.ylabel('Monthly total percipitaiton in ml')
# Out:
# Text(0, 0.5, 'Monthly total percipitaiton in ml')

# %%
plt.figure(figsize=(8, 6))
plt.scatter(monthly_temperature['Year'], monthly_temperature['Snittemperatur'], color='lightcoral', alpha=0.5)
plt.title('Monthly Average Temperature')
plt.xlabel('Year')
plt.ylabel('Monthly average temperature in °C')
# Out:
# Text(0, 0.5, 'Monthly average temperature in °C')

# %%
# Merge the two DataFrames on 'Year' and 'Month'
merged_data = pd.merge(monthly_temperature, monthly_precipitation, on=['Year', 'Month'])

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_data['Snittemperatur'], merged_data['Total_Nederbördsmängd'], color='blue', alpha=0.5)
plt.title('Genomsnittlig månadstemperatur vs total månatlig nederbörd')
plt.xlabel('Snittemperatur °C')
plt.ylabel('Total månatlig nederbörd mm')

plt.show()

# %% [markdown]
# From first glance it appears that average temperature has a very low correlation if any to total monthly percipitation in general.
#
# The data has quite a heteroscedastic relationship.
# We see that from the lowest monthly average temperature, the volume of percipitation is quite low, and there is an upward trend until around 1°C. T This is quite expected as low temperatures is often associated with low pressure, and very try temperature. However, once we get beyond this point, it appears that the data is completey random and a moderate trend is absent.

# %% [markdown]
# ## Setting up the regression test

# %% [markdown]
# #### Assumptions

# %% [markdown]
# 1. Linearity: The relationship between the dependent and independent variables is linear. This assumption can be verified by examining scatter plots of the dependent variable against each independent variable and by analyzing residuals versus fitted values.
#
# 2. Independence: The residuals (errors) are independent of each other. This is crucial when working with time series or panel data, where observations might be correlated over time or across entities. The Durbin-Watson test is one method used to check for autocorrelation in the residuals.
#
# 3. Homoscedasticity: The variance of the residuals is constant across all levels of the independent variables. This means the spread of the residuals should be roughly the same throughout the range of the fitted values. Breusch-Pagan and White tests are among the tests used to detect heteroscedasticity.
#
# 4. No Perfect Multicollinearity: None of the independent variables is a perfect linear function of other explanatory variables. This means that the design matrix (the matrix of independent variables) should be of full rank. Variance inflation factors (VIFs) can be used to check for multicollinearity.
#
# 5. No Endogeneity of Regressors: The error term should not be correlated with the independent variables. If this assumption is violated, it might introduce bias in the OLS estimators. Common causes of endogeneity include omitted variables, measurement errors, and simultaneity. Instrumental variables or two-stage least squares are methods that can address this issue.
#
# 6. Normality of the Error Term: For hypothesis testing to be valid, the error term should be approximately normally distributed, especially in smaller samples. This can be checked using histograms, Q-Q plots, or formal tests like the Jarque-Bera test.
#
# 7. Exogeneity: Expectation of the error term conditional on the independent variables is zero. This ensures that the independent variables are exogenous and there's no omitted variable bias.

# %%
X = monthly_temperature['Snittemperatur']
y = monthly_precipitation['Total_Nederbördsmängd']

# %%
X = sm.add_constant(X)

# Create the OLS model
model = sm.OLS(y, X)

# Fit the model to the data
results = model.fit()

# Display the results
print(results.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Total_Nederbördsmängd   R-squared:                       0.025
# Model:                               OLS   Adj. R-squared:                  0.024
# Method:                    Least Squares   F-statistic:                     24.02
# Date:                   Mon, 06 Nov 2023   Prob (F-statistic):           1.12e-06
# Time:                           20:58:07   Log-Likelihood:                -4832.8
# No. Observations:                    954   AIC:                             9670.
# Df Residuals:                        952   BIC:                             9679.
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             60.9558      1.892     32.219      0.000      57.243      64.669
# ...

# %%
# Create a scatter plot of the data
plt.scatter(X['Snittemperatur'], y, label='Data Points')

# Overlay the regression line
plt.plot(X['Snittemperatur'], results.fittedvalues, color='red', label='Regression Line')

# Add labels and a legend
plt.xlabel('Snittemperatur')
plt.ylabel('Total nederbördsmängd per månad °C')
plt.legend()

# Show the plot
plt.show()

# %%
residuals = results.resid
plt.scatter(results.fittedvalues, residuals)
plt.axhline(y=0, color='r', linestyle='--')  # Add a horizontal line at y=0 for reference
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")

plt.show()

# %%
# Calculate the Breusch-Pagan test
bp_test = sms.het_breuschpagan(results.resid, results.model.exog)

# Extract the test statistics and p-values
test_statistic = bp_test[0]
p_value = bp_test[1]

# Print the test results
print("Breusch-Pagan Test:")
print(f"Test Statistic: {test_statistic}")
print(f"P-Value: {p_value}")

# Interpret the p-value to determine if heteroscedasticity is present
if p_value < 0.05:
    print("Heteroscedasticity is indicated (reject the null hypothesis).")
else:
    print("Heteroscedasticity is not indicated (fail to reject the null hypothesis).")
# Out:
# Breusch-Pagan Test:
# Test Statistic: 4.611902236831791
# P-Value: 0.03175079422096483
# Heteroscedasticity is indicated (reject the null hypothesis).

# %% [markdown]
# There is evidence that the residuals are not constant across the independ variable. A Regression with robust covariance will be used.

# %% [markdown]
# Trying with

# %%
# Fit the model to the data
results_robust = model.fit(cov_type='HC3')

# Display the results
print(results_robust.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Total_Nederbördsmängd   R-squared:                       0.025
# Model:                               OLS   Adj. R-squared:                  0.024
# Method:                    Least Squares   F-statistic:                     26.04
# Date:                   Mon, 06 Nov 2023   Prob (F-statistic):           4.04e-07
# Time:                           20:58:07   Log-Likelihood:                -4832.8
# No. Observations:                    954   AIC:                             9670.
# Df Residuals:                        952   BIC:                             9679.
# Df Model:                              1
# Covariance Type:                     HC3
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             60.9558      1.742     34.990      0.000      57.541      64.370
# ...

# %%
# Create a scatter plot of the data
plt.scatter(X['Snittemperatur'], y, label='Data Points')

# Overlay the regression line
plt.plot(X['Snittemperatur'], results_robust.fittedvalues, color='red', label='Regression Line')

# Add labels and a legend
plt.title('Genomsnittlig månadstemperatur vs total månatlig nederbörd'
)
plt.xlabel('Snittemperatur °C')
plt.ylabel('Total månatlig nederbörd mm')


# Show the plot
plt.show()

# %% [markdown]
# Piecewise regression model to adjust the slope after X = 0
