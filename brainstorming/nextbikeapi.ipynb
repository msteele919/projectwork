# %%
from nextbike_api.client import Client
import json

# %%
print(dir(Client))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowed_url_params', '_build_url', '_check_allowed_query_keys', 'all_countries', 'country']

# %%
c = Client()
country_info = c.country('se')
print(json.dumps(country_info, indent = 4))
# Out:
# {
#     "countries": [
#         {
#             "lat": 57.7005,
#             "lng": 11.9504,
#             "zoom": 10,
#             "name": "Styr & St\u00e4ll (Sweden, G\u00f6teborg)",
#             "hotline": "+46317679438",
#             "domain": "zg",
#             "language": "sv",
#             "email": "styrochstall@nextbike.com",
#             "timezone": "Europe/Berlin",
#             "currency": "SEK",
#             "country_calling_code": "+46",
#             "system_operator_address": "nextbike Sverige AB, Fl\u00f6jelbergsgatan 7 B, 431 37 M\u00f6lndal",
#             "country": "SE",
#             "country_name": "Sweden",
#             "terms": "https://styrochstall.se/xx/terms/#202211",
#             "policy": "https://styrochstall.se/xx/privacy/",
#             "website": "https://styrochstall.se/sv/",
#             "show_bike_types": false,
#             "show_bike_type_groups": false,
#             "show_free_racks": false,
#             "booked_bikes": 0,
# ...

# %%
print(c.country('se'))
# Out:
# {'countries': [{'lat': 57.7005, 'lng': 11.9504, 'zoom': 10, 'name': 'Styr & Ställ (Sweden, Göteborg)', 'hotline': '+46317679438', 'domain': 'zg', 'language': 'sv', 'email': 'styrochstall@nextbike.com', 'timezone': 'Europe/Berlin', 'currency': 'SEK', 'country_calling_code': '+46', 'system_operator_address': 'nextbike Sverige AB, Flöjelbergsgatan 7 B, 431 37 Mölndal', 'country': 'SE', 'country_name': 'Sweden', 'terms': 'https://styrochstall.se/xx/terms/#202211', 'policy': 'https://styrochstall.se/xx/privacy/', 'website': 'https://styrochstall.se/sv/', 'show_bike_types': False, 'show_bike_type_groups': False, 'show_free_racks': False, 'booked_bikes': 0, 'set_point_bikes': 1872, 'available_bikes': 1452, 'capped_available_bikes': False, 'no_registration': False, 'pricing': 'https://styrochstall.se/xx/prices/', 'vat': '25', 'faq_url': 'https://styrochstall.se/xx/faq/', 'store_uri_android': 'https://play.google.com/store/apps/details?id=de.nextbike', 'store_uri_ios': 'https://apps.apple.com
# ...
